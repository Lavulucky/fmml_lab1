# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavulucky/fmml_lab1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 06:23:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   167MB/s    in 0.4s
#
# 2024-03-28 06:23:09 (167 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27588  1704.00083v1  Adaptive tracking-by-detection approaches are ...    cs
# 25652  1511.00438v3  With the rapid increase of users of wearable c...    cs
# 26437  1610.05267v1  Despite the highest classification accuracy in...    cs
# 7757   1803.01785v1  We consider learning of submodular functions f...  stat
# 14273  1601.06259v1  Linear independence testing is a fundamental i...  stat
# ...             ...                                                ...   ...
# 20827  1703.04862v1  Dempster-Shafer theory of evidence is widely a...    cs
# 33355   1304.3200v1  For small number of equations, systems of line...    cs
# 11745  1611.01170v1  Safeguarding privacy in machine learning is hi...    cs
# 7336   1711.10781v1  Tensors are multidimensional arrays of numeric...  stat
# 22300  1512.05219v1  When learning a hidden Markov model (HMM), seq...  stat
#
#                                                    title  year  \
# 27588  Efficient Asymmetric Co-Tracking using Uncerta...  2017
# 25652  Semantic Summarization of Egocentric Photo Str...  2015
# 26437  Rule Extraction Algorithm for Deep Neural Netw...  2016
# 7757              Differentiable Submodular Maximization  2018
# 14273  Minimax Lower Bounds for Linear Independence T...  2016
# ...                                                  ...   ...
# 20827  Exploring the Combination Rules of D Numbers F...  2017
# 33355  An Approach to Solve Linear Equations Using a ...  2013
# 11745  PrivLogit: Efficient Privacy-preserving Logist...  2016
# 7336   Introduction to Tensor Decompositions and thei...  2017
# 22300  Learning a Hybrid Architecture for Sequence Re...  2015
#
#                                                 keywords
# 27588  [detection, approaches, arbitrary, classificat...
# 25652  [automatic, retrieval, summarization, techniqu...
# 26437  [classification, varieties, application, artif...
# 7757   [submodular, functions, functions, important, ...
# 14273  [independence, fundamental, information, theor...
# ...                                                  ...
# 20827  [uncertainty, modelling, knowledge, reasoning,...
# 33355  [equations, sometimes, equations, classical, t...
# 11745  [safeguarding, desirable, especially, collabor...
# 7336   [multidimensional, numerical, therefore, gener...
# 22300  [observations, complemented, variables, genera...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27588    [detection, approaches, arbitrary, classificat...
# 25652    [automatic, retrieval, summarization, techniqu...
# 26437    [classification, varieties, application, artif...
# 7757     [submodular, functions, functions, important, ...
# 14273    [independence, fundamental, information, theor...
#                                ...
# 10405    [successfully, engineering, economics, dynamic...
# 894      [heuristic, optimisers, configuration, variabl...
# 18189    [interpret, electroencephalogram, recording, a...
# 18931    [distribution, variables, structure, represent...
# 20463    [partially, observable, processes, associated,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8866 words.
# Out of those 4545 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c16348f-431c-4578-98fa-fb8c4a500cb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c16348f-431c-4578-98fa-fb8c4a500cb3")) {                    Plotly.newPlot(                        "8c16348f-431c-4578-98fa-fb8c4a500cb3",                        [{"x":["evaluating","introduce","efficiency","demonstrate","detectors","unbounded","approaches","sophisticated","arbitrary","cooperation","furthermore","misclassification","accumulating","performance","techniques","mechanism","conducted","efficient","asymmetric","borderline","uncertainty","classification","benchmark","baselines","effectiveness","experiments","detection","criterion","httpsgithubcomimatge","uniqueness","redundancy","addresses","informative","diversity","perspective","relevance","experimental","egocentric","evaluation","summarization","available","summarizing","automatically","retrieval","different","automatic","evaluated","satisfaction","algorithm","extraction","acceptability","considering","disadvantage","researchers","application","algorithms","pedagogical","comprehensible","explanation","recognition","thoroughly","artificial","structure","contribution","varieties","achieving","innovative","submodular","interpreting","theoretical","subsequently","maximization","functions","approximately","selection","optimizing","objective","sequences","differentiate","smoothness","combinatorial","polynomial","optimization","characterize","applications","differentiable","guarantees","synthetic","important","recommendation","separately","typically","theoretically","maximized","distributions","determine","fundamental","uncorrelated","regression","dimensional","information","multivariate","covariance","connections","procedure","independence","theoretic","statistical","distribution","representing","constructed","similarity","resulting","aggregate","descriptions","prediction","aggregating","optimized","performances","ensembling","downloaded","precision","complementary","procedures","advantage","functional","competition","structural","contemporary","unbalanced","increased","candidate","alignments","ensembles","competitive","variables","specificities","efficiently","separable","boltzmann","depending","communities","equivalent","extension","naturally","instantiate","regularizer","projections","previously","respectively","transport","divergences","classical","regularizers","divergence","dimensions","regularization","solutions","reference","penalties","generalizes","regularized","framework","illustrate","alternate","corresponding","attitudes","discovering","identifies","independent","algebraic","environment","principle","dependent","clustering","diagnosis","individual","hierarchical","addressed","induction","expressed","thousands","attribute","transformations","behaviors","corresponds","requirements","formulation","introduces","formulations","accuracies","controlled","presented","unfortunately","combination","categorization","parameter","amplitudes","correcting","deconvolution"],"y":[53,343,148,589,36,11,425,35,73,8,183,11,9,930,363,119,94,413,9,2,87,512,205,64,207,659,336,42,1,11,21,48,44,49,77,38,356,12,271,28,341,11,211,124,748,203,135,24,815,129,4,60,3,69,252,576,3,5,19,389,13,145,356,67,8,73,13,15,9,156,23,34,210,31,162,49,177,113,7,16,41,69,312,49,422,28,63,139,342,30,29,112,40,6,107,74,87,1,127,170,719,27,20,53,130,23,41,161,223,57,62,126,154,18,36,254,11,57,40,2,2,79,41,27,113,34,33,68,14,4,38,70,11,15,125,131,3,174,12,17,30,11,54,83,72,3,16,22,115,98,11,4,89,4,18,43,79,148,58,2,37,36,586,73,6,123,1,29,21,116,14,117,53,59,124,44,104,112,38,17,43,36,34,48,27,32,56,85,73,19,23,50,197,32,157,28,124,2,13,14],"type":"bar"},{"x":["evaluating","introduce","efficiency","demonstrate"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4545,), (4545, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Pooling</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Modelling</span> <span style=''>Spatial</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Relations</span> <span style=''>for</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.6209150326797387);'>Retrieval</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7611940298507462);'>Annotation</span> <br/><br/><span style=''>Over</span> <span style=''>the</span> <span style=''>last</span> <span style=''>two</span> <span style=''>decades</span> <span style=''>we</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>witnessed</span> <span style=''>strong</span> <span style=''>progress</span> <span style=''>on</span> <span style=''>modeling</span> <span style=''>visual</span> <span style=''>object</span> <span style=''>classes</span> <span style=''>scenes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3103448275862069);'>attributes</span> <span style=''>that</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>contributed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.562043795620438);'>automated</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprisingly</span> <span style=''>little</span> <span style=''>progress</span> <span style=''>has</span> <span style=''>been</span> <span style=''>made</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporating</span> <span style=''>a</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.32091097308488625);'>representation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8507462686567164);'>reasoning</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>process</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>pooling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>relations</span> <span style=''>and</span> <span style=''>show</span> <span style=''>how</span> <span style=''>it</span> <span style=''>improves</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6209150326797387);'>retrieval</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8684210526315789);'>annotations</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>spatial</span> <span style=''>language</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>language</span> <span style=''>we</span> <span style=''>argue</span> <span style=''>for</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>acquires</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.32091097308488625);'>representation</span> <span style=''>of</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fixed</span> <span style=''>effects</span> <span style=''>testing</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>linear</span> <span style=''>mixed</span> <span style=''>models</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>pharmacokinetic</span> <span style=''>drug</span> <span style=''>dosage</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>allocation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>personalized</span> <span style=''>medicine</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marketing</span> <span style=''>mix</span> <span style=''>(4Ps)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendations</span> <span style=''>require</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>best</span> <span style=''>decision</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>test</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>p</span> <span style=''>value</span> <span style=''>for</span> <span style=''>testing</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>linear</span> <span style=''>mixed</span> <span style=''>models</span> <span style=''>A</span> <span style=''>robust</span> <span style=''>matching</span> <span style=''>moment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>is</span> <span style=''>used</span> <span style=''>for</span> <span style=''>creating</span> <span style=''>a</span> <span style=''>test</span> <span style=''>that</span> <span style=''>adapts</span> <span style=''>to</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>sparsity</span> <span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style=''>at</span> <span style=''>a</span> <span style=''>cluster</span> <span style=''>level</span> <span style=''>is</span> <span style=''>constant</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>test</span> <span style=''>is</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>and</span> <span style=''>unbiased</span> <span style=''>even</span> <span style=''>when</span> <span style=''>the</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Randomized</span> <span style=''>Skeleton</span> <span style=''>Sets</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>fast</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>reliably</span> <span style=''>recovers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>shaped</span> <span style=''>data</span> <span style=''>clusters</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughout</span> <span style=''>data</span> <span style=''>streams</span> <span style=''>Unlike</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>k</span> <span style=''>means</span> <span style=''>or</span> <span style=''>k</span> <span style=''>medoid</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>make</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.44);'>restrictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(255, 0, 0, 0.40703517587939697);'>assumptions</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.6402877697841726);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>such</span> <span style=''>as</span> <span style=''>DBScan</span> <span style=''>or</span> <span style=''>DenStream</span> <span style=''>it</span> <span style=''>gives</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3319057815845825);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>To</span> <span style=''>achieve</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.39428571428571435);'>represent</span> <span style=''>each</span> <span style=''>cluster</span> <span style=''>by</span> <span style=''>a</span> <span style=''>skeleton</span> <span style=''>set</span> <span style=''>which</span> <span style=''>is</span> <span style=''>updated</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>continuously</span> <span style=''>as</span> <span style=''>new</span> <span style=''>data</span> <span style=''>is</span> <span style=''>seen</span> <span style=''>A</span> <span style=''>skeleton</span> <span style=''>set</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>weighted</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>where</span> <span style=''>weights</span> <span style=''>encode</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.45945945945945943);'>densities</span> <span style=''>The</span> <span style=''>size</span> <span style=''>of< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>PWLS</span> <span style=''>ULTRA</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>and</span> <span style=''>Learning</span> <span style=''>Based</span> <span style=''>Approach</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Dose</span> <span style=''>3D</span> <span style=''>CT</span> <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reconstruction</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>computed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tomography</span> <span style=''>(CT)</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>methods</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduce</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>radiation</span> <span style=''>exposure</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>high</span> <span style=''>image</span> <span style=''>quality</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>area</span> <span style=''>of</span> <span style=''>research</span> <span style=''>in</span> <span style=''>low</span> <span style=''>dose</span> <span style=''>CT</span> <span style=''>(LDCT)</span> <span style=''>imaging</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalized</span> <span style=''>weighted</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>(PWLS)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>method</span> <span style=''>that</span> <span style=''>exploits</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>Union</span> <span style=''>of</span> <span style=''>Learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>TRAnsforms</span> <span style=''>(PWLS</span> <span style=''>ULTRA)</span> <span style=''>The</span> <span style=''>union</span> <span style=''>of</span> <span style=''>square</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>is</span> <span style=''>pre</span> <span style=''>learned</span> <span style=''>from</span> <span style=''>numerous</span> <span style=''>image</span> <span style=''>patches</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>CT</span> <span style=''>images</span> <span style=''>or</span> <span style=''>volumes</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>PWLS</span> <span style=''>based</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style=''>between</span> <span style=''>a</span> <span style=''>CT</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>step</span> <span style=''>and</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>coding</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07213930348258707)
# 	processing (0.10305614783226724)
# 	segmentation (0.06538734896943853)
# 	knowledge (0.13326226012793177)
# 	architecture (0.09417199715707178)
# 	detection (0.11940298507462686)
# 	information (0.2555081734186212)
# 	convolutional (0.12260127931769722)
# 	different (0.2658137882018479)
# 	recognition (0.13823738450604123)
#
# Some Statistics words are:
# 	variables (0.1364551863041289)
# 	statistical (0.15256797583081572)
# 	distribution (0.17673716012084592)
# 	stochastic (0.14954682779456194)
# 	theoretical (0.15659617321248742)
# 	estimation (0.18076535750251763)
# 	algorithm (0.3987915407854985)
# 	inference (0.1933534743202417)
# 	dimensional (0.1908358509566969)
# 	regression (0.18580060422960726)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="69f8e829-a343-437a-afbb-778d6d069eb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69f8e829-a343-437a-afbb-778d6d069eb0")) {                    Plotly.newPlot(                        "69f8e829-a343-437a-afbb-778d6d069eb0",                        [{"x":["evaluating","introduce","efficiency","demonstrate","detectors","unbounded","approaches","sophisticated","arbitrary","cooperation","furthermore","misclassification","accumulating","performance","techniques","mechanism","conducted","efficient","asymmetric","borderline","uncertainty","classification","benchmark","baselines","effectiveness","experiments","detection","criterion","httpsgithubcomimatge","uniqueness","redundancy","addresses","informative","diversity","perspective","relevance","experimental","egocentric","evaluation","summarization","available","summarizing","automatically","retrieval","different","automatic","evaluated","satisfaction","algorithm","extraction","acceptability","considering","disadvantage","researchers","application","algorithms","pedagogical","comprehensible","explanation","recognition","thoroughly","artificial","structure","contribution","varieties","achieving","innovative","submodular","interpreting","theoretical","subsequently","maximization","functions","approximately","selection","optimizing","objective","sequences","differentiate","smoothness","combinatorial","polynomial","optimization","characterize","applications","differentiable","guarantees","synthetic","important","recommendation","separately","typically","theoretically","maximized","distributions","determine","fundamental","uncorrelated","regression","dimensional","information","multivariate","covariance","connections","procedure","independence","theoretic","statistical","distribution","representing","constructed","similarity","resulting","aggregate","descriptions","prediction","aggregating","optimized","performances","ensembling","downloaded","precision","complementary","procedures","advantage","functional","competition","structural","contemporary","unbalanced","increased","candidate","alignments","ensembles","competitive","variables","specificities","efficiently","separable","boltzmann","depending","communities","equivalent","extension","naturally","instantiate","regularizer","projections","previously","respectively","transport","divergences","classical","regularizers","divergence","dimensions","regularization","solutions","reference","penalties","generalizes","regularized","framework","illustrate","alternate","corresponding","attitudes","discovering","identifies","independent","algebraic","environment","principle","dependent","clustering","diagnosis","individual","hierarchical","addressed","induction","expressed","thousands","attribute","transformations","behaviors","corresponds","requirements","formulation","introduces","formulations","accuracies","controlled","presented","unfortunately","combination","categorization","parameter","amplitudes","correcting","deconvolution","denoising","estimation","simulated","successfully","projection","restoration","averaging","filtering","knowledge","occurrences","correlation","biomedical","association","embedding","relatedness","contextual","occurrence","representation","particular","favorably","standards","improving","incorporating","importance","judgments","distributional","integrating","frequencies","traditional","interactions","attractive","parameters","literature","capability","constraints","component","architectures","published","architecture","processing","convolutional","experience","constrained","sacrificing","exploration","flexibility","preserving","attention","comprehensively","convolution","tensorflow","deceptive","characteristics ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	forecasters
# 	abstention
# 	parametrically
# 	uncorrupted
# 	nonnegativity
# 	colombian
# 	capitalizing
# 	rightarrow
# 	reparametrization
# 	reparametrizations
# 	modulating
# 	unbalancedness
# 	looseness
# 	geometries
# 	conformalized
# 	isometric
# 	regularised
# 	collinearity
# 	whitening
# 	feedbacks
# Some words which never appear in Statistics papers:
# 	egocentric
# 	acceptability
# 	disadvantage
# 	amplitudes
# 	deceptive
# 	competitions
# 	spectrally
# 	compositing
# 	noteworthy
# 	shortcuts
# 	fluctuation
# 	diagrammatic
# 	categorisation
# 	ontological
# 	crossover
# 	chromosomes
# 	synchronized
# 	hospitals
# 	termination
# 	monocular

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059507419305492e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7466666666666667
